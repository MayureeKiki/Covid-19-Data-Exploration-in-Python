# %% [markdown]
# ## Intro Python Pandas ##

# %%
import pandas as pd
df=pd.read_csv("confirmed-cases-since-120864.csv")
df
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0        816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1        816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2        816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3        816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4        816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 213287  1030277     21/8/2021     20/8/2021   ชาย  47.0   ปี    Thailand
# 213288  1030278     21/8/2021     20/8/2021   ชาย  79.0   ปี    Thailand
# 213289  1030279     21/8/2021     20/8/2021   ชาย  29.0   ปี    Thailand
# 213290  1030280     21/8/2021     20/8/2021   ชาย  31.0   ปี    Thailand
# 213291  1030281     21/8/2021     20/8/2021   ชาย  46.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %%
df.head()
# Out:
#       No. announce_date Notified date   sex   age Unit nationality  \
# 0  816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1  816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2  816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3  816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4  816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
#
#   province_of_isolation                                         risk  \
# 0              เชียงราย                                        อื่นๆ
# 1              เชียงราย                                        อื่นๆ
# 2              เชียงราย                                        อื่นๆ
# 3              เชียงราย                                        อื่นๆ
# 4              เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset
# 0               NaN               NaN
# 1               NaN               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213292 entries, 0 to 213291
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   No.                    213292 non-null  int64
#  1   announce_date          213292 non-null  object
#  2   Notified date          213292 non-null  object
#  3   sex                    204047 non-null  object
#  4   age                    198386 non-null  float64
#  5   Unit                   198386 non-null  object
#  6   nationality            198511 non-null  object
#  7   province_of_isolation  213292 non-null  object
#  8   risk                   213292 non-null  object
#  9   province_of_onset      185670 non-null  object
#  10  district_of_onset      174040 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 17.9+ MB

# %%
df = df[['No.', 'announce_date', 'sex', 'age', 'province_of_isolation', 'risk' ]]
df.head()
# Out:
#       No. announce_date   sex   age province_of_isolation  \
# 0  816990     12/8/2021   ชาย   7.0              เชียงราย
# 1  816991     12/8/2021   ชาย   1.0              เชียงราย
# 2  816992     12/8/2021   ชาย  35.0              เชียงราย
# 3  816993     12/8/2021  หญิง  33.0              เชียงราย
# 4  816994     12/8/2021  หญิง  14.0              เชียงราย
#
#                                           risk
# 0                                        อื่นๆ
# 1                                        อื่นๆ
# 2                                        อื่นๆ
# 3                                        อื่นๆ
# 4  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้

# %% [markdown]
# ## 1.ความเสียงของการติดโควิด-19 ##

# %%
df['risk'].value_counts()
# Out:
# risk
# สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                                       88413
# อื่นๆ                                                                             52893
# การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน                                  29868
# อยู่ระหว่างการสอบสวน                                                              25537
# ระบุไม่ได้                                                                         5531
# สถานที่ทำงาน                                                                       3918
# ทัณฑสถาน/เรือนจำ                                                                   3164
# ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว                                      2191
# บุคลากรด้านการแพทย์และสาธารณสุข                                                     897
# อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น      373
# ตรวจก่อนทำหัตถการ                                                                   238
# ...

# %% [markdown]
# ## 2.อายุของผู้ป่วยโควิด-19

# %%
df.describe()
# Out:
#                 No.            age
# count  2.132920e+05  198386.000000
# mean   9.236355e+05      36.174134
# std    6.157224e+04      17.732531
# min    8.169900e+05       1.000000
# 25%    8.703128e+05      24.000000
# 50%    9.236355e+05      35.000000
# 75%    9.769582e+05      48.000000
# max    1.030281e+06     119.000000

# %%
df['age'].hist()
# Out:
# <Axes: >

# %%
df['age'].hist(bins=[0, 20, 40, 60, 80, 100])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['font.family']= 'tahoma' 
#เปลี่ยนฟอนต์เป้น tahoma เพื่อรองรับภาษาไทย

# %%
df['age'].hist(bins=[0, 20, 40, 60, 80, 100])
# Out:
# <Axes: >

# %% [markdown]
# ## วันนี้ติดเชื่อเท่าไหร่ แยกตามแพศ ##

# %%
df[df['province_of_isolation'] == 'ปทุมธานี']
# Out:
#             No. announce_date   sex   age province_of_isolation  \
# 1199     818189     12/8/2021   ชาย   NaN              ปทุมธานี
# 1200     818190     12/8/2021   ชาย  47.0              ปทุมธานี
# 1201     818191     12/8/2021  หญิง  83.0              ปทุมธานี
# 1202     818192     12/8/2021  หญิง  37.0              ปทุมธานี
# 1203     818193     12/8/2021   ชาย  61.0              ปทุมธานี
# ...         ...           ...   ...   ...                   ...
# 213132  1030122     21/8/2021  หญิง  32.0              ปทุมธานี
# 213133  1030123     21/8/2021  หญิง  34.0              ปทุมธานี
# 213134  1030124     21/8/2021  หญิง  29.0              ปทุมธานี
# 213135  1030125     21/8/2021  หญิง  28.0              ปทุมธานี
# 213162  1030152     21/8/2021   ชาย  38.0              ปทุมธานี
#
#                                                risk
# 1199                                     ระบุไม่ได้
# 1200                                     ระบุไม่ได้
# ...

# %%
df.query("province_of_isolation == 'ปทุมธานี' & announce_date == '12/8/2021'")
df.groupby('sex').count()['No.'].plot.bar()
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# ## 5.แนวโน้มจำนวนผู้ป่วย ##

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213292 entries, 0 to 213291
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   No.                    213292 non-null  int64
#  1   announce_date          213292 non-null  object
#  2   sex                    204047 non-null  object
#  3   age                    198386 non-null  float64
#  4   province_of_isolation  213292 non-null  object
#  5   risk                   213292 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.8+ MB

# %%
df.head(1)
# Out:
#       No. announce_date  sex  age province_of_isolation   risk
# 0  816990     12/8/2021  ชาย  7.0              เชียงราย  อื่นๆ

# %%
#change "announce_date" data type column object to  datetiome type for can group data
df.insert(0, 'date', pd.to_datetime(df['announce_date'], format='%d/%m/%Y'), True)
df
# Out:
#              date      No. announce_date   sex   age province_of_isolation  \
# 0      2021-08-12   816990     12/8/2021   ชาย   7.0              เชียงราย
# 1      2021-08-12   816991     12/8/2021   ชาย   1.0              เชียงราย
# 2      2021-08-12   816992     12/8/2021   ชาย  35.0              เชียงราย
# 3      2021-08-12   816993     12/8/2021  หญิง  33.0              เชียงราย
# 4      2021-08-12   816994     12/8/2021  หญิง  14.0              เชียงราย
# ...           ...      ...           ...   ...   ...                   ...
# 213287 2021-08-21  1030277     21/8/2021   ชาย  47.0         กรุงเทพมหานคร
# 213288 2021-08-21  1030278     21/8/2021   ชาย  79.0         กรุงเทพมหานคร
# 213289 2021-08-21  1030279     21/8/2021   ชาย  29.0         กรุงเทพมหานคร
# 213290 2021-08-21  1030280     21/8/2021   ชาย  31.0         กรุงเทพมหานคร
# 213291 2021-08-21  1030281     21/8/2021   ชาย  46.0                ชลบุรี
#
#                                                risk
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213292 entries, 0 to 213291
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date                   213292 non-null  datetime64[ns]
#  1   No.                    213292 non-null  int64
#  2   announce_date          213292 non-null  object
#  3   sex                    204047 non-null  object
#  4   age                    198386 non-null  float64
#  5   province_of_isolation  213292 non-null  object
#  6   risk                   213292 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 11.4+ MB

# %%
# แต่ละวันมีผู้ป่วยกี่คน
df.groupby('date').count()
# Out:
#               No.  announce_date    sex    age  province_of_isolation   risk
# date
# 2021-08-12  22782          22782  20892  21394                  22782  22782
# 2021-08-13  23418          23418  22548  21800                  23418  23418
# 2021-08-14  22086          22086  21201  21128                  22086  22086
# 2021-08-15  21882          21882  20576  19745                  21882  21882
# 2021-08-16  21157          21157  20622  19945                  21157  21157
# 2021-08-17  20128          20128  19127  17978                  20128  20128
# 2021-08-18  20515          20515  19861  19230                  20515  20515
# 2021-08-19  20902          20902  20041  19339                  20902  20902
# 2021-08-20  19851          19851  19187  18773                  19851  19851
# 2021-08-21  20571          20571  19992  19054                  20571  20571

# %%
df.groupby('date').count()['No.'].plot.line(figsize=(10,5))
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## อัตราผู้ติดเชื้อ ##

# %%
pop_df = pd.read_csv('thai_population_63.csv')
pop_df
# Out:
#             จังหวัด      รวม  น้อยกว่า 1 ปี   1 ปี   2 ปี   3 ปี   4 ปี  \
# 0     กรุงเทพมหานคร  5588222          34808  39431  41803  44389  45504
# 1       สมุทรปราการ  1351479          11150  12175  12765  13390  13719
# 2           นนทบุรี  1276745           9180  10137  10566  11212  11419
# 3          ปทุมธานี  1176412           9664  10561  11151  12160  11978
# 4   พระนครศรีอยุธยา   819088           6714   7209   7536   7784   7699
# ..              ...      ...            ...    ...    ...    ...    ...
# 72             ตรัง   640574           5410   6163   6451   6777   6936
# 73           พัทลุง   523077           4266   4772   5122   5319   5284
# 74          ปัตตานี   726015          11404  11606  12094  12552  12235
# 75             ยะลา   538602           8138   8650   8765   8801   8802
# 76         นราธิวาส   804429          11878  12066  12658  13037  12717
#
#      5 ปี   6 ปี   7 ปี  ...  96 ปี  97 ปี  98 ปี  99 ปี  100 ปี  \
# ...

# %%
#selection column (การเลือก column 2 column ต้องใส่วงเล็บเหลี่ยม 2 ครั้ง) ใส่ตารานี้ไว้ในตัวแปล pop_df
pop_df = pop_df[['จังหวัด', 'รวม']]
pop_df.head()
# Out:
#            จังหวัด      รวม
# 0    กรุงเทพมหานคร  5588222
# 1      สมุทรปราการ  1351479
# 2          นนทบุรี  1276745
# 3         ปทุมธานี  1176412
# 4  พระนครศรีอยุธยา   819088

# %%
df
# Out:
#              date      No. announce_date   sex   age province_of_isolation  \
# 0      2021-08-12   816990     12/8/2021   ชาย   7.0              เชียงราย
# 1      2021-08-12   816991     12/8/2021   ชาย   1.0              เชียงราย
# 2      2021-08-12   816992     12/8/2021   ชาย  35.0              เชียงราย
# 3      2021-08-12   816993     12/8/2021  หญิง  33.0              เชียงราย
# 4      2021-08-12   816994     12/8/2021  หญิง  14.0              เชียงราย
# ...           ...      ...           ...   ...   ...                   ...
# 213287 2021-08-21  1030277     21/8/2021   ชาย  47.0         กรุงเทพมหานคร
# 213288 2021-08-21  1030278     21/8/2021   ชาย  79.0         กรุงเทพมหานคร
# 213289 2021-08-21  1030279     21/8/2021   ชาย  29.0         กรุงเทพมหานคร
# 213290 2021-08-21  1030280     21/8/2021   ชาย  31.0         กรุงเทพมหานคร
# 213291 2021-08-21  1030281     21/8/2021   ชาย  46.0                ชลบุรี
#
#                                                risk
# ...

# %%
#count the patients by the provinces //.reset_index() เพื่อให้ข้อมุลเป็น Column
province_df = df.groupby('province_of_isolation').count()['No.'].reset_index()
province_df
# Out:
#    province_of_isolation    No.
# 0                    กทม    722
# 1                 กระบี่    152
# 2          กรุงเทพมหานคร  44484
# 3              กาญจนบุรี   3016
# 4              กาฬสินธุ์   1295
# ..                   ...    ...
# 73              เพชรบุรี   1025
# 74             เพชรบูรณ์   1456
# 75                   เลย    570
# 76                  แพร่    319
# 77            แม่ฮ่องสอน     37
#
# [78 rows x 2 columns]

# %%
df.insert(2, 'province', df['province_of_isolation'].replace('กทม', 'กรุงเทพมหานคร'), True)

# %%
province_df = df.groupby('province').count()['No.'].reset_index()
province_df
# Out:
#          province    No.
# 0          กระบี่    152
# 1   กรุงเทพมหานคร  45206
# 2       กาญจนบุรี   3016
# 3       กาฬสินธุ์   1295
# 4       กำแพงเพชร   1347
# ..            ...    ...
# 72       เพชรบุรี   1025
# 73      เพชรบูรณ์   1456
# 74            เลย    570
# 75           แพร่    319
# 76     แม่ฮ่องสอน     37
#
# [77 rows x 2 columns]

# %%
pop_df
# Out:
#             จังหวัด      รวม
# 0     กรุงเทพมหานคร  5588222
# 1       สมุทรปราการ  1351479
# 2           นนทบุรี  1276745
# 3          ปทุมธานี  1176412
# 4   พระนครศรีอยุธยา   819088
# ..              ...      ...
# 72             ตรัง   640574
# 73           พัทลุง   523077
# 74          ปัตตานี   726015
# 75             ยะลา   538602
# 76         นราธิวาส   804429
#
# [77 rows x 2 columns]

# %%
prov_pop_df = pd.merge(province_df, pop_df, left_on='province', right_on='จังหวัด')
prov_pop_df
# Out:
#          province    No.        จังหวัด      รวม
# 0          กระบี่    152         กระบี่   477770
# 1   กรุงเทพมหานคร  45206  กรุงเทพมหานคร  5588222
# 2       กาญจนบุรี   3016      กาญจนบุรี   891976
# 3       กาฬสินธุ์   1295      กาฬสินธุ์   977175
# 4       กำแพงเพชร   1347      กำแพงเพชร   714118
# ..            ...    ...            ...      ...
# 72       เพชรบุรี   1025       เพชรบุรี   482193
# 73      เพชรบูรณ์   1456      เพชรบูรณ์   981940
# 74            เลย    570            เลย   638736
# 75           แพร่    319           แพร่   437350
# 76     แม่ฮ่องสอน     37     แม่ฮ่องสอน   284549
#
# [77 rows x 4 columns]

# %%
#อัคราการติดเชื้อต่อประชากร 1 แสนคน
prov_pop_df['rate'] = prov_pop_df['No.'] * 100000 / prov_pop_df['รวม']
prov_pop_df
# Out:
#          province    No.        จังหวัด      รวม        rate
# 0          กระบี่    152         กระบี่   477770   31.814471
# 1   กรุงเทพมหานคร  45206  กรุงเทพมหานคร  5588222  808.951398
# 2       กาญจนบุรี   3016      กาญจนบุรี   891976  338.125689
# 3       กาฬสินธุ์   1295      กาฬสินธุ์   977175  132.524880
# 4       กำแพงเพชร   1347      กำแพงเพชร   714118  188.624289
# ..            ...    ...            ...      ...         ...
# 72       เพชรบุรี   1025       เพชรบุรี   482193  212.570485
# 73      เพชรบูรณ์   1456      เพชรบูรณ์   981940  148.277899
# 74            เลย    570            เลย   638736   89.238747
# 75           แพร่    319           แพร่   437350   72.939293
# 76     แม่ฮ่องสอน     37     แม่ฮ่องสอน   284549   13.003033
#
# [77 rows x 5 columns]

# %%
#set_index('จังหวัด') เอา column จังหวัดให้กลายเป็น Index เพื่อจะเอา index นี้มา plot แผนภูมิ แกน x
top10_prov_df= prov_pop_df.sort_values('rate', ascending=False).head(10).set_index('จังหวัด')
top10_prov_df
# Out:
#                     province    No.      รวม         rate
# จังหวัด
# สมุทรสาคร          สมุทรสาคร  17579   586199  2998.810984
# สมุทรสงคราม      สมุทรสงคราม   2025   192052  1054.401933
# สมุทรปราการ      สมุทรปราการ  14051  1351479  1039.675792
# ชลบุรี                ชลบุรี  13639  1566885   870.453160
# นครนายก              นครนายก   2206   260081   848.197292
# กรุงเทพมหานคร  กรุงเทพมหานคร  45206  5588222   808.951398
# ระนอง                  ระนอง   1494   194372   768.629226
# อ่างทอง              อ่างทอง   2049   276584   740.823764
# สระบุรี              สระบุรี   4550   643828   706.710488
# ฉะเชิงเทรา        ฉะเชิงเทรา   4641   720718   643.941181

# %%
top10_prov_df[['No.', 'rate']].plot.bar(figsize=(10,5))
# Out:
# <Axes: xlabel='จังหวัด'>
